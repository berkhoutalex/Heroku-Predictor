# %%
import pandas as pd
reg = pd.read_csv("../notebooks/regular_season_stats.csv", encoding = 'latin-1')

# %%
reg.head()
# Out:
#       TeamName  TeamID  Season   G   W   L        Eff  FGM        FG%  \
# 0  Abilene Chr    1101    2014  21   2  19  15.714286  427  40.550807
# 1  Abilene Chr    1101    2015  28   7  21  19.892857  600  40.485830
# 2  Abilene Chr    1101    2016  27   9  18  26.703704  643  44.162088
# 3  Abilene Chr    1101    2017  25   9  16  28.240000  611  45.836459
# 4  Abilene Chr    1101    2018  27  12  15  31.555556  689  45.180328
#
#         eFG% ...   OOR      OORB%  ODR      ODRB%  OAst  OTO      OTOV%  OStl  \
# 0  47.198481 ...   218  33.798450  506  75.074184   327  255  15.784782   147
# 1  47.334683 ...   281  33.814681  725  75.836820   362  377  18.117683   164
# 2  50.515110 ...   232  27.619048  681  75.498891   347  363  17.215540   138
# 3  52.475619 ...   266  31.742243  626  76.809816   340  370  18.745567   151
# 4  50.918033 ...   268  29.944134  676  73.478261   325  418  19.329301   176
#
#    OBlk  OPF
# 0   105  392
# 1   119  463
# 2    89  531
# 3    79  431
# ...

# %%
reg.columns
# Out:
# Index(['TeamName', 'TeamID', 'Season', 'G', 'W', 'L', 'Eff', 'FGM', 'FG%',
#        'eFG%', 'FGA', 'FGM3', 'FG3%', 'FGA3', 'FTM', 'FT%', 'FTA', 'OR',
#        'ORB%', 'DR', 'DRB%', 'Ast', 'TO', 'TOV%', 'Stl', 'Blk', 'PF', 'OFGM',
#        'OFGA', 'OFG%', 'OeFG%', 'OFGM3', 'OFGA3', 'OFG3%', 'OFTM', 'OFTA',
#        'OFT%', 'OOR', 'OORB%', 'ODR', 'ODRB%', 'OAst', 'OTO', 'OTOV%', 'OStl',
#        'OBlk', 'OPF'],
#       dtype='object')

# %%
import statsmodels.api as sm
#df.loc[:, df.columns != 'Price'] for every column but one

Y = reg['W']
X = reg[['eFG%','ORB%', 'DRB%', 'TOV%','OeFG%','ODRB%','OTOV%']]
model = sm.OLS(Y,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      W   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1835.
# Date:                Tue, 10 Apr 2018   Prob (F-statistic):               0.00
# Time:                        15:14:41   Log-Likelihood:                -3953.7
# No. Observations:                1755   AIC:                             7921.
# Df Residuals:                    1748   BIC:                             7960.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# eFG%           0.9737      0.019     49.977      0.000       0.935       1.012
# ...
